# %%
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My Drive/[2024-2025] AN2DL/Lecture 5

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import keras_cv

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import requests
from io import BytesIO
# import cv2
# from PIL import Image
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

import albumentations as A
from tensorflow.keras.saving import register_keras_serializable
# Out:
# 2.16.1

# %%
data = np.load('/kaggle/input/data-mars2/augmented_dataset_1.npz')
print(data.files)
# Out:
# ['X_train', 'X_val', 'X_test', 'X_to_predict']

# %%
#X_train = data['X_train']
#y_train = data['y_train']
#X_val = data['X_val']
#y_val = data['y_val']
#X_test = data['X_test']
#y_test = data['y_test']
#X_to_predict = data['X_to_predict']
#class_weights = data['class_weights']

#print("Shape of TRAIN:", " X",X_train.shape, " y",y_train.shape)
#print("Shape of VAL:", " X",X_val.shape, " y",y_val.shape)
#print("Shape of TEST:", " X",X_test.shape, " y",y_test.shape)
#print("Shape of X_to_predict:", X_to_predict.shape)

#targets = ['Background', 'Soil', 'Bedrock', 'Sand', 'Big Rock']
#NUM_CLASSES = len(targets)
data = np.load('/kaggle/input/data-mars/augmented_dataset-3.npz')
X_train = data['X_train']
X_val = data['X_val']
X_test = data['X_test']
X_to_predict = data['X_to_predict']

print("Shape of X_train:", X_train.shape)
print("Shape of X_val:", X_val.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of X_to_predict:", X_to_predict.shape)

targets = ['Background', 'Soil', 'Bedrock', 'Sand', 'Big Rock']
NUM_CLASSES = len(targets)
# Out:
# Shape of X_train: (50100, 2, 64, 128)
# Shape of X_val: (6250, 2, 64, 128)
# Shape of X_test: (6275, 2, 64, 128)
# Shape of X_to_predict: (10022, 64, 128)

# %%
#def np_to_tf(X, y, batch_size = 64, shuffle_buffer_size=1000):
#    X = X.astype(np.uint8)
#    y = y.astype(np.uint8)
#    
#    dataset = tf.data.Dataset.from_tensor_slices((X, y))

#    dataset = dataset.shuffle(buffer_size=shuffle_buffer_size)
    
#    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
#    print(dataset.element_spec)
#    print(f"Num of batchs: {len(dataset)}, Num of images: {len(dataset)*batch_size}")

#    return dataset

#X_train_tf = np_to_tf(X_train, y_train)
#X_val_tf = np_to_tf(X_val, y_val)
#X_test_tf = np_to_tf(X_test, y_test)
def np_to_tf(X, batch_size = 64):
    # Split the array into images and masks
    X_images = X[:, 0]  # Grayscale images 
    X_masks = X[:, 1]   # Masks (shape: 
    
    # Reshape the images to 3 channels (by repeating the grayscale channel)
    X_images_rgb = np.repeat(X_images[..., np.newaxis], 3, axis=-1)  
    
    # Reshape the masks to have a single channel
    X_masks = X_masks[..., np.newaxis]  
    
    # Ensure images have dtype float32 and masks have dtype int32
    X_images_rgb = X_images_rgb.astype(np.uint8)
    X_masks = X_masks.astype(np.uint8)
    
    # Create a TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices((X_images_rgb, X_masks))
    
    # Prefetch for performance
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    # Print dataset element spec to verify the shape
    print(dataset.element_spec)
    print(f"Num of batchs: {len(dataset)}, Num of images: {len(dataset)*batch_size}")

    return dataset

X_train_tf = np_to_tf(X_train)
X_val_tf = np_to_tf(X_val)
X_test_tf = np_to_tf(X_test)
# Out:
# (TensorSpec(shape=(None, 64, 128, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(None, 64, 128, 1), dtype=tf.uint8, name=None))
# Num of batchs: 783, Num of images: 50112
# (TensorSpec(shape=(None, 64, 128, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(None, 64, 128, 1), dtype=tf.uint8, name=None))
# Num of batchs: 98, Num of images: 6272
# (TensorSpec(shape=(None, 64, 128, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(None, 64, 128, 1), dtype=tf.uint8, name=None))
# Num of batchs: 99, Num of images: 6336

# %%
#def np_to_tf_no_mask(X, batch_size = 64):
#    X_images = X  
    
#    X_images_rgb = np.repeat(X_images[..., np.newaxis], 3, axis=-1)  # (20920, 64, 128, 3)
    
#    X_images_rgb = X_images_rgb.astype(np.uint8)
    
#    dataset = tf.data.Dataset.from_tensor_slices(X_images_rgb)
    
#    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
#    print(dataset.element_spec)
#    print(f"Num of batchs: {len(dataset)}, Num of images: {len(dataset)*batch_size}")

#    return dataset

#X_to_predict_tf = np_to_tf_no_mask(X_to_predict)
def np_to_tf_no_mask(X, batch_size = 64):
    # Split the array into images and masks
    X_images = X  # Grayscale images 
    
    # Reshape the images to 3 channels (by repeating the grayscale channel)
    X_images_rgb = np.repeat(X_images[..., np.newaxis], 3, axis=-1)  
    
    # Reshape the masks to have a single channel
    
    # Ensure images have dtype float32 and masks have dtype int32
    X_images_rgb = X_images_rgb.astype(np.uint8)
    
    # Create a TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices(X_images_rgb)
    
    # Prefetch for performance
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
    # Print dataset element spec to verify the shape
    print(dataset.element_spec)
    print(f"Num of batchs: {len(dataset)}, Num of images: {len(dataset)*batch_size}")

    return dataset

X_to_predict_tf = np_to_tf_no_mask(X_to_predict)
# Out:
# TensorSpec(shape=(None, 64, 128, 3), dtype=tf.uint8, name=None)
# Num of batchs: 157, Num of images: 10048

# %%
# Set learning rate for the optimiser
LEARNING_RATE = 1e-4

# Set early stopping patience threshold
PATIENCE = 20

# Set maximum number of training epochs
EPOCHS = 200

# %%
# Define custom Mean Intersection Over Union metric
@register_keras_serializable()
class MeanIntersectionOverUnion(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, labels_to_exclude=None, name="mean_iou", dtype=None):
        super(MeanIntersectionOverUnion, self).__init__(num_classes=num_classes, name=name, dtype=dtype)
        if labels_to_exclude is None:
            labels_to_exclude = [0]  # Default to excluding label 0
        self.labels_to_exclude = labels_to_exclude

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert predictions to class labels
        y_pred = tf.math.argmax(y_pred, axis=-1)

        # Flatten the tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])

        # Apply mask to exclude specified labels
        for label in self.labels_to_exclude:
            mask = tf.not_equal(y_true, label)
            y_true = tf.boolean_mask(y_true, mask)
            y_pred = tf.boolean_mask(y_pred, mask)

        # Update the state
        return super().update_state(y_true, y_pred, sample_weight)

def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, dropout_rate = 0.3, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # if x.shape[-1] != input_tensor.shape[-1]:  # If number of channels don't match
       # input_tensor = tfkl.Conv2D(filters, kernel_size=1, padding='same', name=name + 'conv_1x1_input')(input_tensor)

    # x = tfkl.Add()([x, input_tensor]) # add residual connections
    # Return the transformed tensor
    return x

# %%
class NCutLoss2D(tf.keras.losses.Loss):
    def __init__(self, radius=4, sigma_1=5.0, sigma_2=1.0, name="NCutLoss2D"):
        super().__init__(name=name)
        self.radius = radius
        self.sigma_1 = sigma_1
        self.sigma_2 = sigma_2

    def gaussian_kernel(self, radius, sigma):
        """
        Generate a 2D Gaussian kernel.
        """
        size = 2 * radius + 1
        x, y = np.meshgrid(np.arange(size) - radius, np.arange(size) - radius)
        kernel = np.exp(-(x**2 + y**2) / (2 * sigma**2))
        kernel /= np.sum(kernel)
        return tf.convert_to_tensor(kernel, dtype=tf.float32)

    def call(self, y_true, y_pred):
        """
        Compute the continuous N-Cut loss.
        :param y_true: Ground truth labels (sparse integer labels).
        :param y_pred: Predicted class probabilities.
        :return: Continuous N-Cut loss.
        """
        # Ensure y_true matches the shape of y_pred
        y_true_resized = tf.image.resize(y_true, tf.shape(y_pred)[1:3], method='nearest')
        y_true_resized = tf.cast(tf.round(y_true_resized), tf.int32)

        # Convert sparse labels to one-hot format
        num_classes = tf.shape(y_pred)[-1]
        y_true_one_hot = tf.one_hot(y_true_resized, num_classes)
        y_true_one_hot = tf.cast(y_true_one_hot, tf.float32)

        kernel = self.gaussian_kernel(self.radius, self.sigma_1)
        kernel = tf.reshape(kernel, [2 * self.radius + 1, 2 * self.radius + 1, 1, 1])

        def compute_class_loss(k):
            """
            Compute the loss for a single class.
            """
            class_probs = y_pred[..., k]  # Shape: (batch_size, height, width)
            class_probs = tf.expand_dims(class_probs, axis=-1)  # Shape: (batch_size, height, width, 1)
            class_true = y_true_one_hot[..., k]  # Shape: (batch_size, height, width)
            #class_true = tf.expand_dims(class_true, axis=-1)  # Shape: (batch_size, height, width, 1)

            # Class mean pixel value
            class_mean = tf.reduce_sum(class_probs * class_true, axis=(1, 2), keepdims=True) / (
                tf.reduce_sum(class_probs, axis=(1, 2), keepdims=True) + 1e-5
            )

            # Difference from class mean
            diff = tf.reduce_sum((class_true - class_mean) ** 2, axis=-1, keepdims=True)

            # Compute weights
            weights = tf.exp(-diff ** 2 / (self.sigma_2 ** 2))

            # Compute N-cut numerator and denominator
            spatially_smoothed_probs = tf.nn.depthwise_conv2d(
                class_probs * weights, kernel, strides=[1, 1, 1, 1], padding="SAME"
            )
            numerator = tf.reduce_sum(class_probs * spatially_smoothed_probs)
            denominator = tf.reduce_sum(class_probs * tf.nn.depthwise_conv2d(weights, kernel, strides=[1, 1, 1, 1], padding="SAME"))

            return tf.abs(numerator / (denominator + 1e-6))

        # Use tf.map_fn to iterate over classes
        class_losses = tf.map_fn(compute_class_loss, tf.range(num_classes), dtype=tf.float32)
        total_loss = tf.cast(num_classes, tf.float32) - tf.reduce_sum(class_losses)
        return total_loss

def combined_loss(y_true, y_pred):
    # Loss U-Net 1: focalizzata sull'output intermedio (esempio MSE)
    n_cut_loss = NCutLoss2D(radius=4, sigma_1=5.0, sigma_2=1.0)
    loss_unet1 = n_cut_loss(y_true - y_pred)
    # Loss U-Net 2: ricostruzione finale
    loss_unet2 = tf.reduce_mean(tf.square(y_true - y_pred))
    return 0.5 * loss_unet1 + 0.5 * loss_unet2

def dice_loss_multiclass_excluding_background(y_true, y_pred, smooth=1e-6):
    # One-hot encode y_true to match the shape of y_pred
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=tf.shape(y_pred)[-1])  # (batch, H, W, num_classes)

    # Exclude background (assumed to be class 0)
    y_true = y_true[..., 1:]  # Exclude channel 0
    y_pred = y_pred[..., 1:]  # Exclude channel 0

    # Reshape to (batch_size * image_size, num_classes)
    y_true = tf.reshape(y_true, (-1, tf.shape(y_pred)[-1]))
    y_pred = tf.reshape(y_pred, (-1, tf.shape(y_pred)[-1]))

    # Compute Dice coefficient for each class
    intersection = tf.reduce_sum(y_true * y_pred, axis=0)
    union = tf.reduce_sum(y_true, axis=0) + tf.reduce_sum(y_pred, axis=0)
    dice = (2. * intersection + smooth) / (union + smooth)

    # Average Dice Loss across all non-background classes
    return 1 - tf.reduce_mean(dice)

def dice_loss_multiclass_with_background_weight(y_true, y_pred, background_weight=0.001, other_class_weight=0.05, smooth=1e-6):
    # One-hot encode y_true to match the shape of y_pred
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=tf.shape(y_pred)[-1])  # (batch, H, W, num_classes)

    # Reshape to (batch_size * image_size, num_classes)
    y_true = tf.reshape(y_true, (-1, tf.shape(y_pred)[-1]))
    y_pred = tf.reshape(y_pred, (-1, tf.shape(y_pred)[-1]))

    # Compute Dice coefficient for each class
    intersection = tf.reduce_sum(y_true * y_pred, axis=0)
    union = tf.reduce_sum(y_true, axis=0) + tf.reduce_sum(y_pred, axis=0)
    dice = (2. * intersection + smooth) / (union + smooth)

    # Create class-specific weights
    num_classes = tf.shape(y_pred)[-1]
    class_weights = tf.ones(num_classes)
    class_weights = tf.tensor_scatter_nd_update(
        class_weights, 
        [[0]],  # index of background class 
        [background_weight]  # new weight for background
    )

    class_weights = tf.tensor_scatter_nd_update(
        class_weights, 
        [[1]],  
        [other_class_weight]  
    )

    class_weights = tf.tensor_scatter_nd_update(
        class_weights, 
        [[2]],  
        [other_class_weight]  
    )

    class_weights = tf.tensor_scatter_nd_update(
        class_weights, 
        [[3]],  
        [other_class_weight]  
    )

    # Apply class weights to Dice coefficients
    weighted_dice = dice * class_weights

    # Average Dice Loss across all classes
    return 1 - tf.reduce_mean(weighted_dice)


from scipy.ndimage import distance_transform_edt

def dice_loss_multiclass_excluding_background(y_true, y_pred, smooth=1e-6):
    # One-hot encode y_true to match the shape of y_pred
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=tf.shape(y_pred)[-1])  # (batch, H, W, num_classes)

    # Exclude background (assumed to be class 0)
    y_true = y_true[..., 1:]  # Exclude channel 0
    y_pred = y_pred[..., 1:]  # Exclude channel 0

    # Reshape to (batch_size * image_size, num_classes)
    y_true = tf.reshape(y_true, (-1, tf.shape(y_pred)[-1]))
    y_pred = tf.reshape(y_pred, (-1, tf.shape(y_pred)[-1]))

    # Compute Dice coefficient for each class
    intersection = tf.reduce_sum(y_true * y_pred, axis=0)
    union = tf.reduce_sum(y_true, axis=0) + tf.reduce_sum(y_pred, axis=0)
    dice = (2. * intersection + smooth) / (union + smooth)

    # Average Dice Loss across all non-background classes
    return 1 - tf.reduce_mean(dice)

def categorical_focal_loss(gamma=2.0, alpha=0.25):
    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, K.epsilon(), 1 - K.epsilon())
        
        cross_entropy = -y_true * tf.math.log(y_pred)
        focal_loss = alpha * (1 - y_pred) ** gamma * cross_entropy
        
        return tf.reduce_mean(tf.reduce_sum(focal_loss, axis=-1))
    
    return loss

def compute_distance_map(y_true):
    batch_size = y_true.shape[0]
    distance_maps = np.zeros_like(y_true)
    for i in range(batch_size):
        for c in range(y_true.shape[-1]):
            distance_maps[i, :, :, c] = distance_transform_edt(y_true[i, :, :, c])
    return distance_maps

def boundary_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    
    sobel_filter_x = tf.constant([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]], dtype=tf.float32)
    sobel_filter_x = sobel_filter_x[:, :, tf.newaxis, tf.newaxis]
    sobel_filter_y = tf.constant([[-1, -2, -1], [0, 0, 0], [1, 2, 1]], dtype=tf.float32)
    sobel_filter_y = sobel_filter_y[:, :, tf.newaxis, tf.newaxis]

    grad_x = tf.nn.conv2d(y_true, sobel_filter_x, strides=[1, 1, 1, 1], padding='SAME')
    grad_y = tf.nn.conv2d(y_true, sobel_filter_y, strides=[1, 1, 1, 1], padding='SAME')

    gradient_magnitude = tf.sqrt(tf.square(grad_x) + tf.square(grad_y))

    normalized_boundary = tf.clip_by_value(gradient_magnitude, 0, 1)

    boundary_loss_value = tf.reduce_mean(normalized_boundary * tf.abs(y_pred - y_true))

    return boundary_loss_value

def combined_loss(y_true, y_pred):
    loss_dice = dice_loss_multiclass_excluding_background(y_true, y_pred)
    loss_focal = categorical_focal_loss()(y_true, y_pred)  
    loss_boundary = boundary_loss(y_true, y_pred)
    return 0.7 * loss_dice + 0.15 * loss_focal + 0.15 * loss_boundary

# %%
# 1st U-Net

def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, dropout_rate = 0.3, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # if x.shape[-1] != input_tensor.shape[-1]:  # If number of channels don't match
       # input_tensor = tfkl.Conv2D(filters, kernel_size=1, padding='same', name=name + 'conv_1x1_input')(input_tensor)
    
    # x = tfkl.Add()([x, input_tensor]) # add residual connections
    # Return the transformed tensor
    return x

def get_unet_model(input_shape=(64, 128, 3), num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    down_block_3 = unet_block(d2, 128, name='down_block3_')
    d3 = tfkl.MaxPooling2D()(down_block_3)

    down_block_4 = unet_block(d3, 256, name='down_block4_')
    d4 = tfkl.MaxPooling2D()(down_block_4)

    down_block_5 = unet_block(d4, 512, name='down_block5_')
    d5 = tfkl.MaxPooling2D()(down_block_5)

    # Bottleneck
    bottleneck = unet_block(d5, 1024, name='bottleneck')
    bottleneck = tfkl.Dropout(0.5)(bottleneck)

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_5])
    u1 = unet_block(u1, 512, name='up_block1_')
    
    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_4])
    u2 = unet_block(u2, 256, name='up_block2_')
    
    u3 = tfkl.UpSampling2D()(u2)
    u3 = tfkl.Concatenate()([u3, down_block_3])
    u3 = unet_block(u3, 128, name='up_block3_')
    
    u4 = tfkl.UpSampling2D()(u3)
    u4 = tfkl.Concatenate()([u4, down_block_2])
    u4 = unet_block(u4, 64, name='up_block4_')
    
    u5 = tfkl.UpSampling2D()(u4)
    u5 = tfkl.Concatenate()([u5, down_block_1])
    u5 = unet_block(u5, 32, name='up_block5_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u5)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
    return model

# %%
from tensorflow.keras import Model

def build_wnet(input_shape=(64, 128, 3)):
    # First U-Net
    unet1 = get_unet_model()
    
    # Second U-Net
    unet2 = get_unet_model()

    # Input 
    inputs = tf.keras.Input(input_shape)
    
    unet1_output = unet1(inputs)
    
    # Adjusting channels
    adjusted_output = tfkl.Conv2D(3, kernel_size=(1, 1), padding='same')(unet1_output)

    unet2_output = unet2(adjusted_output)
    
    # Combined Model
    return Model(inputs, unet2_output)

# WNet model
model = build_wnet()

# %%
# Print a detailed summary of the model with expanded nested layers and trainable parameters.
model.summary(expand_nested=True, show_trainable=True)

# Generate and display a graphical representation of the model architecture.
tf.keras.utils.plot_model(model, show_trainable=True, expand_nested=True, dpi=70)

# Compile the model
print("Compiling model...")
model.compile(
    #loss=dice_loss_multiclass_with_background_weight,
    loss=dice_loss_multiclass_with_background_weight,
    optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE),
    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]
)
print("Model compiled!")

# Setup callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',  
    factor=0.5,          
    patience=3,          
    min_lr=1e-6          
)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 64, 128, 3)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ functional_1 (Functional)   │ (None, 64, 128, 5)    │ 31,466,885 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ input_layer            │ (None, 64, 128, 3)    │          0 │   -   │
# │ (InputLayer)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_conv1      │ (None, 64, 128, 32)   │        896 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_bn1        │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 64, 128, 32)   │          0 │   -   │
# │ down_block1_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_conv2      │ (None, 64, 128, 32)   │      9,248 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_bn2        │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 64, 128, 32)   │          0 │   -   │
# │ down_block1_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d          │ (None, 32, 64, 32)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_conv1      │ (None, 32, 64, 64)    │     18,496 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_bn1        │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 32, 64, 64)    │          0 │   -   │
# │ down_block2_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_conv2      │ (None, 32, 64, 64)    │     36,928 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_bn2        │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 32, 64, 64)    │          0 │   -   │
# │ down_block2_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_1        │ (None, 16, 32, 64)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_conv1      │ (None, 16, 32, 128)   │     73,856 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_bn1        │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 16, 32, 128)   │          0 │   -   │
# │ down_block3_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_conv2      │ (None, 16, 32, 128)   │    147,584 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_bn2        │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 16, 32, 128)   │          0 │   -   │
# │ down_block3_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_2        │ (None, 8, 16, 128)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_conv1      │ (None, 8, 16, 256)    │    295,168 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_bn1        │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 8, 16, 256)    │          0 │   -   │
# │ down_block4_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_conv2      │ (None, 8, 16, 256)    │    590,080 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_bn2        │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 8, 16, 256)    │          0 │   -   │
# │ down_block4_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_3        │ (None, 4, 8, 256)     │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_conv1      │ (None, 4, 8, 512)     │  1,180,160 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_bn1        │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 4, 8, 512)     │          0 │   -   │
# │ down_block5_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_conv2      │ (None, 4, 8, 512)     │  2,359,808 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_bn2        │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 4, 8, 512)     │          0 │   -   │
# │ down_block5_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_4        │ (None, 2, 4, 512)     │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckconv1        │ (None, 2, 4, 1024)    │  4,719,616 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckbn1          │ (None, 2, 4, 1024)    │      4,096 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckactivation1  │ (None, 2, 4, 1024)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckconv2        │ (None, 2, 4, 1024)    │  9,438,208 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckbn2          │ (None, 2, 4, 1024)    │      4,096 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckactivation2  │ (None, 2, 4, 1024)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ dropout (Dropout)      │ (None, 2, 4, 1024)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d          │ (None, 4, 8, 1024)    │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate            │ (None, 4, 8, 1536)    │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_conv1        │ (None, 4, 8, 512)     │  7,078,400 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_bn1          │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_activation1  │ (None, 4, 8, 512)     │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_conv2        │ (None, 4, 8, 512)     │  2,359,808 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_bn2          │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_activation2  │ (None, 4, 8, 512)     │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_1        │ (None, 8, 16, 512)    │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_1          │ (None, 8, 16, 768)    │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_conv1        │ (None, 8, 16, 256)    │  1,769,728 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_bn1          │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_activation1  │ (None, 8, 16, 256)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_conv2        │ (None, 8, 16, 256)    │    590,080 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_bn2          │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_activation2  │ (None, 8, 16, 256)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_2        │ (None, 16, 32, 256)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_2          │ (None, 16, 32, 384)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_conv1        │ (None, 16, 32, 128)   │    442,496 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_bn1          │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_activation1  │ (None, 16, 32, 128)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_conv2        │ (None, 16, 32, 128)   │    147,584 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_bn2          │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_activation2  │ (None, 16, 32, 128)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_3        │ (None, 32, 64, 128)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_3          │ (None, 32, 64, 192)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_conv1        │ (None, 32, 64, 64)    │    110,656 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_bn1          │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_activation1  │ (None, 32, 64, 64)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_conv2        │ (None, 32, 64, 64)    │     36,928 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_bn2          │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_activation2  │ (None, 32, 64, 64)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_4        │ (None, 64, 128, 64)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_4          │ (None, 64, 128, 96)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_conv1        │ (None, 64, 128, 32)   │     27,680 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_bn1          │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_activation1  │ (None, 64, 128, 32)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_conv2        │ (None, 64, 128, 32)   │      9,248 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_bn2          │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_activation2  │ (None, 64, 128, 32)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ output_layer (Conv2D)  │ (None, 64, 128, 5)    │        165 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv2d (Conv2D)             │ (None, 64, 128, 3)    │         18 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ functional_3 (Functional)   │ (None, 64, 128, 5)    │ 31,466,885 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ input_layer            │ (None, 64, 128, 3)    │          0 │   -   │
# │ (InputLayer)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_conv1      │ (None, 64, 128, 32)   │        896 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_bn1        │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 64, 128, 32)   │          0 │   -   │
# │ down_block1_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_conv2      │ (None, 64, 128, 32)   │      9,248 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block1_bn2        │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 64, 128, 32)   │          0 │   -   │
# │ down_block1_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_5        │ (None, 32, 64, 32)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_conv1      │ (None, 32, 64, 64)    │     18,496 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_bn1        │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 32, 64, 64)    │          0 │   -   │
# │ down_block2_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_conv2      │ (None, 32, 64, 64)    │     36,928 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block2_bn2        │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 32, 64, 64)    │          0 │   -   │
# │ down_block2_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_6        │ (None, 16, 32, 64)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_conv1      │ (None, 16, 32, 128)   │     73,856 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_bn1        │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 16, 32, 128)   │          0 │   -   │
# │ down_block3_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_conv2      │ (None, 16, 32, 128)   │    147,584 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block3_bn2        │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 16, 32, 128)   │          0 │   -   │
# │ down_block3_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_7        │ (None, 8, 16, 128)    │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_conv1      │ (None, 8, 16, 256)    │    295,168 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_bn1        │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 8, 16, 256)    │          0 │   -   │
# │ down_block4_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_conv2      │ (None, 8, 16, 256)    │    590,080 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block4_bn2        │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 8, 16, 256)    │          0 │   -   │
# │ down_block4_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_8        │ (None, 4, 8, 256)     │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_conv1      │ (None, 4, 8, 512)     │  1,180,160 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_bn1        │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 4, 8, 512)     │          0 │   -   │
# │ down_block5_activation1     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_conv2      │ (None, 4, 8, 512)     │  2,359,808 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ down_block5_bn2        │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └                        │ (None, 4, 8, 512)     │          0 │   -   │
# │ down_block5_activation2     │                       │            │       │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ max_pooling2d_9        │ (None, 2, 4, 512)     │          0 │   -   │
# │ (MaxPooling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckconv1        │ (None, 2, 4, 1024)    │  4,719,616 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckbn1          │ (None, 2, 4, 1024)    │      4,096 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckactivation1  │ (None, 2, 4, 1024)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckconv2        │ (None, 2, 4, 1024)    │  9,438,208 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckbn2          │ (None, 2, 4, 1024)    │      4,096 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ bottleneckactivation2  │ (None, 2, 4, 1024)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ dropout_1 (Dropout)    │ (None, 2, 4, 1024)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_5        │ (None, 4, 8, 1024)    │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_5          │ (None, 4, 8, 1536)    │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_conv1        │ (None, 4, 8, 512)     │  7,078,400 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_bn1          │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_activation1  │ (None, 4, 8, 512)     │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_conv2        │ (None, 4, 8, 512)     │  2,359,808 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_bn2          │ (None, 4, 8, 512)     │      2,048 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block1_activation2  │ (None, 4, 8, 512)     │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_6        │ (None, 8, 16, 512)    │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_6          │ (None, 8, 16, 768)    │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_conv1        │ (None, 8, 16, 256)    │  1,769,728 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_bn1          │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_activation1  │ (None, 8, 16, 256)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_conv2        │ (None, 8, 16, 256)    │    590,080 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_bn2          │ (None, 8, 16, 256)    │      1,024 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block2_activation2  │ (None, 8, 16, 256)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_7        │ (None, 16, 32, 256)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_7          │ (None, 16, 32, 384)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_conv1        │ (None, 16, 32, 128)   │    442,496 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_bn1          │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_activation1  │ (None, 16, 32, 128)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_conv2        │ (None, 16, 32, 128)   │    147,584 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_bn2          │ (None, 16, 32, 128)   │        512 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block3_activation2  │ (None, 16, 32, 128)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_8        │ (None, 32, 64, 128)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_8          │ (None, 32, 64, 192)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_conv1        │ (None, 32, 64, 64)    │    110,656 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_bn1          │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_activation1  │ (None, 32, 64, 64)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_conv2        │ (None, 32, 64, 64)    │     36,928 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_bn2          │ (None, 32, 64, 64)    │        256 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block4_activation2  │ (None, 32, 64, 64)    │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_sampling2d_9        │ (None, 64, 128, 64)   │          0 │   -   │
# │ (UpSampling2D)              │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ concatenate_9          │ (None, 64, 128, 96)   │          0 │   -   │
# │ (Concatenate)               │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_conv1        │ (None, 64, 128, 32)   │     27,680 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_bn1          │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_activation1  │ (None, 64, 128, 32)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_conv2        │ (None, 64, 128, 32)   │      9,248 │   Y   │
# │ (Conv2D)                    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_bn2          │ (None, 64, 128, 32)   │        128 │   Y   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ up_block5_activation2  │ (None, 64, 128, 32)   │          0 │   -   │
# │ (Activation)                │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │    └ output_layer (Conv2D)  │ (None, 64, 128, 5)    │        165 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 62,933,788 (240.07 MB)
#  Trainable params: 62,909,724 (239.98 MB)
#  Non-trainable params: 24,064 (94.00 KB)
# Compiling model...
# Model compiled!

# %%
# Train the all model
history = model.fit(
    X_train_tf,
    epochs=EPOCHS,
    validation_data=X_val_tf,
    #class_weight = class_weights_dict,
    callbacks=[early_stopping, reduce_lr],
    verbose=2
).history

# Calculate and print the final validation accuracy
final_val_meanIoU = round(max(history['val_mean_iou'])* 100, 2)
print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734098665.723161      66 service.cc:145] XLA service 0x78fd24002c80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734098665.723218      66 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1734098700.803389      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 783/783 - 272s - 348ms/step - accuracy: 0.5138 - loss: 0.9794 - mean_iou: 0.1507 - val_accuracy: 0.4053 - val_loss: 0.9844 - val_mean_iou: 0.2521 - learning_rate: 1.0000e-04
# Epoch 2/200
# 783/783 - 163s - 209ms/step - accuracy: 0.5710 - loss: 0.9688 - mean_iou: 0.1886 - val_accuracy: 0.5454 - val_loss: 0.9808 - val_mean_iou: 0.3638 - learning_rate: 1.0000e-04
# Epoch 3/200
# 783/783 - 163s - 208ms/step - accuracy: 0.5649 - loss: 0.9629 - mean_iou: 0.1896 - val_accuracy: 0.5156 - val_loss: 0.9707 - val_mean_iou: 0.3511 - learning_rate: 1.0000e-04
# Epoch 4/200
# 783/783 - 163s - 209ms/step - accuracy: 0.5824 - loss: 0.9578 - mean_iou: 0.2061 - val_accuracy: 0.4386 - val_loss: 0.9778 - val_mean_iou: 0.2680 - learning_rate: 1.0000e-04
# Epoch 5/200
# 783/783 - 163s - 209ms/step - accuracy: 0.5843 - loss: 0.9523 - mean_iou: 0.2140 - val_accuracy: 0.5366 - val_loss: 0.9776 - val_mean_iou: 0.4443 - learning_rate: 1.0000e-04
# Epoch 6/200
# 783/783 - 163s - 209ms/step - accuracy: 0.5857 - loss: 0.9538 - mean_iou: 0.2078 - val_accuracy: 0.5674 - val_loss: 0.9735 - val_mean_iou: 0.4952 - learning_rate: 1.0000e-04
# Epoch 7/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6002 - loss: 0.9504 - mean_iou: 0.2265 - val_accuracy: 0.5616 - val_loss: 0.9804 - val_mean_iou: 0.4713 - learning_rate: 5.0000e-05
# Epoch 8/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6013 - loss: 0.9454 - mean_iou: 0.2374 - val_accuracy: 0.5611 - val_loss: 0.9802 - val_mean_iou: 0.4733 - learning_rate: 5.0000e-05
# Epoch 9/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6069 - loss: 0.9394 - mean_iou: 0.2565 - val_accuracy: 0.4863 - val_loss: 0.9743 - val_mean_iou: 0.4008 - learning_rate: 5.0000e-05
# Epoch 10/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6088 - loss: 0.9352 - mean_iou: 0.2617 - val_accuracy: 0.5559 - val_loss: 0.9722 - val_mean_iou: 0.4791 - learning_rate: 2.5000e-05
# Epoch 11/200
# 783/783 - 164s - 209ms/step - accuracy: 0.6086 - loss: 0.9319 - mean_iou: 0.2710 - val_accuracy: 0.5880 - val_loss: 0.9702 - val_mean_iou: 0.5306 - learning_rate: 2.5000e-05
# Epoch 12/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6140 - loss: 0.9309 - mean_iou: 0.2728 - val_accuracy: 0.5787 - val_loss: 0.9801 - val_mean_iou: 0.4957 - learning_rate: 2.5000e-05
# Epoch 13/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6156 - loss: 0.9279 - mean_iou: 0.2761 - val_accuracy: 0.5837 - val_loss: 0.9799 - val_mean_iou: 0.5040 - learning_rate: 2.5000e-05
# Epoch 14/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6126 - loss: 0.9270 - mean_iou: 0.2725 - val_accuracy: 0.5868 - val_loss: 0.9797 - val_mean_iou: 0.5073 - learning_rate: 2.5000e-05
# Epoch 15/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6165 - loss: 0.9230 - mean_iou: 0.2821 - val_accuracy: 0.5905 - val_loss: 0.9791 - val_mean_iou: 0.5137 - learning_rate: 1.2500e-05
# Epoch 16/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6181 - loss: 0.9210 - mean_iou: 0.2865 - val_accuracy: 0.5815 - val_loss: 0.9799 - val_mean_iou: 0.5004 - learning_rate: 1.2500e-05
# Epoch 17/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6198 - loss: 0.9199 - mean_iou: 0.2881 - val_accuracy: 0.5970 - val_loss: 0.9794 - val_mean_iou: 0.5226 - learning_rate: 1.2500e-05
# Epoch 18/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6214 - loss: 0.9177 - mean_iou: 0.2952 - val_accuracy: 0.5935 - val_loss: 0.9790 - val_mean_iou: 0.5184 - learning_rate: 6.2500e-06
# Epoch 19/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6226 - loss: 0.9165 - mean_iou: 0.2974 - val_accuracy: 0.5932 - val_loss: 0.9786 - val_mean_iou: 0.5182 - learning_rate: 6.2500e-06
# Epoch 20/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6228 - loss: 0.9156 - mean_iou: 0.2990 - val_accuracy: 0.5945 - val_loss: 0.9792 - val_mean_iou: 0.5198 - learning_rate: 6.2500e-06
# Epoch 21/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6240 - loss: 0.9147 - mean_iou: 0.3013 - val_accuracy: 0.5957 - val_loss: 0.9790 - val_mean_iou: 0.5216 - learning_rate: 3.1250e-06
# Epoch 22/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6244 - loss: 0.9142 - mean_iou: 0.3020 - val_accuracy: 0.5971 - val_loss: 0.9788 - val_mean_iou: 0.5240 - learning_rate: 3.1250e-06
# Epoch 23/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6249 - loss: 0.9136 - mean_iou: 0.3026 - val_accuracy: 0.5976 - val_loss: 0.9789 - val_mean_iou: 0.5244 - learning_rate: 3.1250e-06
# Epoch 24/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6253 - loss: 0.9128 - mean_iou: 0.3037 - val_accuracy: 0.5972 - val_loss: 0.9786 - val_mean_iou: 0.5242 - learning_rate: 1.5625e-06
# Epoch 25/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6257 - loss: 0.9124 - mean_iou: 0.3044 - val_accuracy: 0.5965 - val_loss: 0.9785 - val_mean_iou: 0.5236 - learning_rate: 1.5625e-06
# Epoch 26/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6259 - loss: 0.9120 - mean_iou: 0.3048 - val_accuracy: 0.5972 - val_loss: 0.9785 - val_mean_iou: 0.5243 - learning_rate: 1.5625e-06
# Epoch 27/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6259 - loss: 0.9118 - mean_iou: 0.3052 - val_accuracy: 0.5970 - val_loss: 0.9786 - val_mean_iou: 0.5239 - learning_rate: 1.0000e-06
# Epoch 28/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6262 - loss: 0.9116 - mean_iou: 0.3056 - val_accuracy: 0.5973 - val_loss: 0.9786 - val_mean_iou: 0.5244 - learning_rate: 1.0000e-06
# Epoch 29/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6263 - loss: 0.9114 - mean_iou: 0.3058 - val_accuracy: 0.5977 - val_loss: 0.9786 - val_mean_iou: 0.5250 - learning_rate: 1.0000e-06
# Epoch 30/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6264 - loss: 0.9112 - mean_iou: 0.3062 - val_accuracy: 0.5975 - val_loss: 0.9787 - val_mean_iou: 0.5247 - learning_rate: 1.0000e-06
# Epoch 31/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6267 - loss: 0.9110 - mean_iou: 0.3067 - val_accuracy: 0.5967 - val_loss: 0.9787 - val_mean_iou: 0.5236 - learning_rate: 1.0000e-06
# Epoch 32/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6268 - loss: 0.9111 - mean_iou: 0.3069 - val_accuracy: 0.5984 - val_loss: 0.9785 - val_mean_iou: 0.5262 - learning_rate: 1.0000e-06
# Epoch 33/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6269 - loss: 0.9110 - mean_iou: 0.3068 - val_accuracy: 0.5970 - val_loss: 0.9785 - val_mean_iou: 0.5243 - learning_rate: 1.0000e-06
# Epoch 34/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6271 - loss: 0.9107 - mean_iou: 0.3073 - val_accuracy: 0.5971 - val_loss: 0.9786 - val_mean_iou: 0.5244 - learning_rate: 1.0000e-06
# Epoch 35/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6272 - loss: 0.9106 - mean_iou: 0.3073 - val_accuracy: 0.5972 - val_loss: 0.9786 - val_mean_iou: 0.5243 - learning_rate: 1.0000e-06
# Epoch 36/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6273 - loss: 0.9103 - mean_iou: 0.3079 - val_accuracy: 0.5981 - val_loss: 0.9786 - val_mean_iou: 0.5255 - learning_rate: 1.0000e-06
# Epoch 37/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6275 - loss: 0.9103 - mean_iou: 0.3080 - val_accuracy: 0.5985 - val_loss: 0.9786 - val_mean_iou: 0.5263 - learning_rate: 1.0000e-06
# Epoch 38/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6275 - loss: 0.9101 - mean_iou: 0.3084 - val_accuracy: 0.5976 - val_loss: 0.9787 - val_mean_iou: 0.5249 - learning_rate: 1.0000e-06
# Epoch 39/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6278 - loss: 0.9099 - mean_iou: 0.3088 - val_accuracy: 0.5979 - val_loss: 0.9787 - val_mean_iou: 0.5252 - learning_rate: 1.0000e-06
# Epoch 40/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6279 - loss: 0.9098 - mean_iou: 0.3087 - val_accuracy: 0.5986 - val_loss: 0.9785 - val_mean_iou: 0.5265 - learning_rate: 1.0000e-06
# Epoch 41/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6279 - loss: 0.9097 - mean_iou: 0.3089 - val_accuracy: 0.5987 - val_loss: 0.9785 - val_mean_iou: 0.5265 - learning_rate: 1.0000e-06
# Epoch 42/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6280 - loss: 0.9095 - mean_iou: 0.3092 - val_accuracy: 0.5995 - val_loss: 0.9786 - val_mean_iou: 0.5275 - learning_rate: 1.0000e-06
# Epoch 43/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6281 - loss: 0.9095 - mean_iou: 0.3094 - val_accuracy: 0.5988 - val_loss: 0.9786 - val_mean_iou: 0.5265 - learning_rate: 1.0000e-06
# Epoch 44/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6281 - loss: 0.9092 - mean_iou: 0.3097 - val_accuracy: 0.5989 - val_loss: 0.9786 - val_mean_iou: 0.5266 - learning_rate: 1.0000e-06
# Epoch 45/200
# 783/783 - 162s - 206ms/step - accuracy: 0.6284 - loss: 0.9091 - mean_iou: 0.3100 - val_accuracy: 0.5988 - val_loss: 0.9787 - val_mean_iou: 0.5265 - learning_rate: 1.0000e-06
# Epoch 46/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6282 - loss: 0.9087 - mean_iou: 0.3101 - val_accuracy: 0.5993 - val_loss: 0.9787 - val_mean_iou: 0.5270 - learning_rate: 1.0000e-06
# Epoch 47/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6283 - loss: 0.9088 - mean_iou: 0.3101 - val_accuracy: 0.5989 - val_loss: 0.9785 - val_mean_iou: 0.5267 - learning_rate: 1.0000e-06
# Epoch 48/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6284 - loss: 0.9086 - mean_iou: 0.3102 - val_accuracy: 0.5991 - val_loss: 0.9786 - val_mean_iou: 0.5268 - learning_rate: 1.0000e-06
# Epoch 49/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6285 - loss: 0.9084 - mean_iou: 0.3106 - val_accuracy: 0.5995 - val_loss: 0.9786 - val_mean_iou: 0.5273 - learning_rate: 1.0000e-06
# Epoch 50/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6287 - loss: 0.9083 - mean_iou: 0.3106 - val_accuracy: 0.5988 - val_loss: 0.9787 - val_mean_iou: 0.5262 - learning_rate: 1.0000e-06
# Epoch 51/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6288 - loss: 0.9082 - mean_iou: 0.3110 - val_accuracy: 0.5998 - val_loss: 0.9787 - val_mean_iou: 0.5277 - learning_rate: 1.0000e-06
# Epoch 52/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6289 - loss: 0.9080 - mean_iou: 0.3110 - val_accuracy: 0.5985 - val_loss: 0.9787 - val_mean_iou: 0.5258 - learning_rate: 1.0000e-06
# Epoch 53/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6290 - loss: 0.9079 - mean_iou: 0.3114 - val_accuracy: 0.5999 - val_loss: 0.9786 - val_mean_iou: 0.5279 - learning_rate: 1.0000e-06
# Epoch 54/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6291 - loss: 0.9079 - mean_iou: 0.3115 - val_accuracy: 0.5998 - val_loss: 0.9785 - val_mean_iou: 0.5279 - learning_rate: 1.0000e-06
# Epoch 55/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6291 - loss: 0.9077 - mean_iou: 0.3115 - val_accuracy: 0.5996 - val_loss: 0.9785 - val_mean_iou: 0.5277 - learning_rate: 1.0000e-06
# Epoch 56/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6291 - loss: 0.9076 - mean_iou: 0.3114 - val_accuracy: 0.5995 - val_loss: 0.9785 - val_mean_iou: 0.5276 - learning_rate: 1.0000e-06
# Epoch 57/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6292 - loss: 0.9075 - mean_iou: 0.3119 - val_accuracy: 0.5998 - val_loss: 0.9786 - val_mean_iou: 0.5279 - learning_rate: 1.0000e-06
# Epoch 58/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6293 - loss: 0.9074 - mean_iou: 0.3119 - val_accuracy: 0.5998 - val_loss: 0.9787 - val_mean_iou: 0.5278 - learning_rate: 1.0000e-06
# Epoch 59/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6293 - loss: 0.9072 - mean_iou: 0.3122 - val_accuracy: 0.6000 - val_loss: 0.9785 - val_mean_iou: 0.5282 - learning_rate: 1.0000e-06
# Epoch 60/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6292 - loss: 0.9071 - mean_iou: 0.3122 - val_accuracy: 0.5999 - val_loss: 0.9786 - val_mean_iou: 0.5279 - learning_rate: 1.0000e-06
# Epoch 61/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6293 - loss: 0.9071 - mean_iou: 0.3121 - val_accuracy: 0.5994 - val_loss: 0.9787 - val_mean_iou: 0.5270 - learning_rate: 1.0000e-06
# Epoch 62/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6293 - loss: 0.9071 - mean_iou: 0.3123 - val_accuracy: 0.5999 - val_loss: 0.9786 - val_mean_iou: 0.5280 - learning_rate: 1.0000e-06
# Epoch 63/200
# 783/783 - 164s - 209ms/step - accuracy: 0.6296 - loss: 0.9069 - mean_iou: 0.3125 - val_accuracy: 0.6000 - val_loss: 0.9786 - val_mean_iou: 0.5282 - learning_rate: 1.0000e-06
# Epoch 64/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6294 - loss: 0.9068 - mean_iou: 0.3125 - val_accuracy: 0.6002 - val_loss: 0.9785 - val_mean_iou: 0.5284 - learning_rate: 1.0000e-06
# Epoch 65/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6295 - loss: 0.9066 - mean_iou: 0.3127 - val_accuracy: 0.6001 - val_loss: 0.9785 - val_mean_iou: 0.5284 - learning_rate: 1.0000e-06
# Epoch 66/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6296 - loss: 0.9066 - mean_iou: 0.3126 - val_accuracy: 0.6002 - val_loss: 0.9785 - val_mean_iou: 0.5284 - learning_rate: 1.0000e-06
# Epoch 67/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6296 - loss: 0.9065 - mean_iou: 0.3128 - val_accuracy: 0.5991 - val_loss: 0.9785 - val_mean_iou: 0.5270 - learning_rate: 1.0000e-06
# Epoch 68/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6298 - loss: 0.9063 - mean_iou: 0.3131 - val_accuracy: 0.6003 - val_loss: 0.9785 - val_mean_iou: 0.5287 - learning_rate: 1.0000e-06
# Epoch 69/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6298 - loss: 0.9063 - mean_iou: 0.3131 - val_accuracy: 0.6002 - val_loss: 0.9785 - val_mean_iou: 0.5285 - learning_rate: 1.0000e-06
# Epoch 70/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6297 - loss: 0.9063 - mean_iou: 0.3131 - val_accuracy: 0.6012 - val_loss: 0.9784 - val_mean_iou: 0.5299 - learning_rate: 1.0000e-06
# Epoch 71/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6299 - loss: 0.9062 - mean_iou: 0.3133 - val_accuracy: 0.6003 - val_loss: 0.9785 - val_mean_iou: 0.5287 - learning_rate: 1.0000e-06
# Epoch 72/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6300 - loss: 0.9060 - mean_iou: 0.3918 - val_accuracy: 0.6016 - val_loss: 0.9784 - val_mean_iou: 0.5308 - learning_rate: 1.0000e-06
# Epoch 73/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6301 - loss: 0.9059 - mean_iou: 0.3138 - val_accuracy: 0.6007 - val_loss: 0.9784 - val_mean_iou: 0.5295 - learning_rate: 1.0000e-06
# Epoch 74/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6302 - loss: 0.9058 - mean_iou: 0.3137 - val_accuracy: 0.6021 - val_loss: 0.9784 - val_mean_iou: 0.5315 - learning_rate: 1.0000e-06
# Epoch 75/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6303 - loss: 0.9058 - mean_iou: 0.3135 - val_accuracy: 0.6015 - val_loss: 0.9786 - val_mean_iou: 0.5303 - learning_rate: 1.0000e-06
# Epoch 76/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6301 - loss: 0.9059 - mean_iou: 0.3136 - val_accuracy: 0.6012 - val_loss: 0.9787 - val_mean_iou: 0.5298 - learning_rate: 1.0000e-06
# Epoch 77/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6302 - loss: 0.9057 - mean_iou: 0.3140 - val_accuracy: 0.6009 - val_loss: 0.9785 - val_mean_iou: 0.5295 - learning_rate: 1.0000e-06
# Epoch 78/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6304 - loss: 0.9057 - mean_iou: 0.3141 - val_accuracy: 0.6012 - val_loss: 0.9785 - val_mean_iou: 0.5300 - learning_rate: 1.0000e-06
# Epoch 79/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6305 - loss: 0.9055 - mean_iou: 0.3143 - val_accuracy: 0.6013 - val_loss: 0.9784 - val_mean_iou: 0.5303 - learning_rate: 1.0000e-06
# Epoch 80/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6305 - loss: 0.9056 - mean_iou: 0.3144 - val_accuracy: 0.6019 - val_loss: 0.9784 - val_mean_iou: 0.5312 - learning_rate: 1.0000e-06
# Epoch 81/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6305 - loss: 0.9054 - mean_iou: 0.3143 - val_accuracy: 0.6024 - val_loss: 0.9783 - val_mean_iou: 0.5320 - learning_rate: 1.0000e-06
# Epoch 82/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6307 - loss: 0.9053 - mean_iou: 0.3146 - val_accuracy: 0.6020 - val_loss: 0.9784 - val_mean_iou: 0.5314 - learning_rate: 1.0000e-06
# Epoch 83/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6307 - loss: 0.9052 - mean_iou: 0.3149 - val_accuracy: 0.6028 - val_loss: 0.9784 - val_mean_iou: 0.5324 - learning_rate: 1.0000e-06
# Epoch 84/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6307 - loss: 0.9053 - mean_iou: 0.3148 - val_accuracy: 0.6017 - val_loss: 0.9785 - val_mean_iou: 0.5308 - learning_rate: 1.0000e-06
# Epoch 85/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6309 - loss: 0.9051 - mean_iou: 0.3151 - val_accuracy: 0.6016 - val_loss: 0.9786 - val_mean_iou: 0.5305 - learning_rate: 1.0000e-06
# Epoch 86/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6309 - loss: 0.9050 - mean_iou: 0.3150 - val_accuracy: 0.6021 - val_loss: 0.9786 - val_mean_iou: 0.5312 - learning_rate: 1.0000e-06
# Epoch 87/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6309 - loss: 0.9051 - mean_iou: 0.3938 - val_accuracy: 0.6029 - val_loss: 0.9784 - val_mean_iou: 0.5327 - learning_rate: 1.0000e-06
# Epoch 88/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6311 - loss: 0.9050 - mean_iou: 0.3154 - val_accuracy: 0.6026 - val_loss: 0.9783 - val_mean_iou: 0.5323 - learning_rate: 1.0000e-06
# Epoch 89/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6310 - loss: 0.9051 - mean_iou: 0.3151 - val_accuracy: 0.6022 - val_loss: 0.9783 - val_mean_iou: 0.5318 - learning_rate: 1.0000e-06
# Epoch 90/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6312 - loss: 0.9049 - mean_iou: 0.3153 - val_accuracy: 0.6031 - val_loss: 0.9783 - val_mean_iou: 0.5331 - learning_rate: 1.0000e-06
# Epoch 91/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6313 - loss: 0.9047 - mean_iou: 0.3157 - val_accuracy: 0.6029 - val_loss: 0.9783 - val_mean_iou: 0.5328 - learning_rate: 1.0000e-06
# Epoch 92/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6314 - loss: 0.9047 - mean_iou: 0.3159 - val_accuracy: 0.6024 - val_loss: 0.9783 - val_mean_iou: 0.5320 - learning_rate: 1.0000e-06
# Epoch 93/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6314 - loss: 0.9047 - mean_iou: 0.3159 - val_accuracy: 0.6034 - val_loss: 0.9783 - val_mean_iou: 0.5334 - learning_rate: 1.0000e-06
# Epoch 94/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6315 - loss: 0.9045 - mean_iou: 0.3161 - val_accuracy: 0.6033 - val_loss: 0.9784 - val_mean_iou: 0.5332 - learning_rate: 1.0000e-06
# Epoch 95/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6315 - loss: 0.9046 - mean_iou: 0.3163 - val_accuracy: 0.6032 - val_loss: 0.9783 - val_mean_iou: 0.5332 - learning_rate: 1.0000e-06
# Epoch 96/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6316 - loss: 0.9045 - mean_iou: 0.3163 - val_accuracy: 0.6032 - val_loss: 0.9783 - val_mean_iou: 0.5332 - learning_rate: 1.0000e-06
# Epoch 97/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6317 - loss: 0.9046 - mean_iou: 0.3164 - val_accuracy: 0.6025 - val_loss: 0.9783 - val_mean_iou: 0.5322 - learning_rate: 1.0000e-06
# Epoch 98/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6319 - loss: 0.9044 - mean_iou: 0.3167 - val_accuracy: 0.6038 - val_loss: 0.9783 - val_mean_iou: 0.5340 - learning_rate: 1.0000e-06
# Epoch 99/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6318 - loss: 0.9043 - mean_iou: 0.3167 - val_accuracy: 0.6037 - val_loss: 0.9783 - val_mean_iou: 0.5340 - learning_rate: 1.0000e-06
# Epoch 100/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6320 - loss: 0.9043 - mean_iou: 0.3168 - val_accuracy: 0.6028 - val_loss: 0.9783 - val_mean_iou: 0.5326 - learning_rate: 1.0000e-06
# Epoch 101/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6320 - loss: 0.9041 - mean_iou: 0.3960 - val_accuracy: 0.6040 - val_loss: 0.9782 - val_mean_iou: 0.5346 - learning_rate: 1.0000e-06
# Epoch 102/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6320 - loss: 0.9041 - mean_iou: 0.3169 - val_accuracy: 0.6042 - val_loss: 0.9783 - val_mean_iou: 0.5348 - learning_rate: 1.0000e-06
# Epoch 103/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6319 - loss: 0.9040 - mean_iou: 0.3170 - val_accuracy: 0.6039 - val_loss: 0.9783 - val_mean_iou: 0.5342 - learning_rate: 1.0000e-06
# Epoch 104/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6319 - loss: 0.9039 - mean_iou: 0.3963 - val_accuracy: 0.6034 - val_loss: 0.9784 - val_mean_iou: 0.5334 - learning_rate: 1.0000e-06
# Epoch 105/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6319 - loss: 0.9038 - mean_iou: 0.3963 - val_accuracy: 0.6037 - val_loss: 0.9783 - val_mean_iou: 0.5339 - learning_rate: 1.0000e-06
# Epoch 106/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6321 - loss: 0.9036 - mean_iou: 0.3175 - val_accuracy: 0.6042 - val_loss: 0.9782 - val_mean_iou: 0.5347 - learning_rate: 1.0000e-06
# Epoch 107/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6320 - loss: 0.9035 - mean_iou: 0.3172 - val_accuracy: 0.6051 - val_loss: 0.9782 - val_mean_iou: 0.5362 - learning_rate: 1.0000e-06
# Epoch 108/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6321 - loss: 0.9036 - mean_iou: 0.3967 - val_accuracy: 0.6038 - val_loss: 0.9782 - val_mean_iou: 0.5341 - learning_rate: 1.0000e-06
# Epoch 109/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6320 - loss: 0.9034 - mean_iou: 0.3967 - val_accuracy: 0.6047 - val_loss: 0.9782 - val_mean_iou: 0.5355 - learning_rate: 1.0000e-06
# Epoch 110/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6323 - loss: 0.9032 - mean_iou: 0.3177 - val_accuracy: 0.6040 - val_loss: 0.9783 - val_mean_iou: 0.5344 - learning_rate: 1.0000e-06
# Epoch 111/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6323 - loss: 0.9031 - mean_iou: 0.3974 - val_accuracy: 0.6038 - val_loss: 0.9783 - val_mean_iou: 0.5342 - learning_rate: 1.0000e-06
# Epoch 112/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6323 - loss: 0.9030 - mean_iou: 0.3179 - val_accuracy: 0.6047 - val_loss: 0.9782 - val_mean_iou: 0.5356 - learning_rate: 1.0000e-06
# Epoch 113/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6322 - loss: 0.9029 - mean_iou: 0.3178 - val_accuracy: 0.6031 - val_loss: 0.9783 - val_mean_iou: 0.5331 - learning_rate: 1.0000e-06
# Epoch 114/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6323 - loss: 0.9029 - mean_iou: 0.3181 - val_accuracy: 0.6048 - val_loss: 0.9782 - val_mean_iou: 0.5356 - learning_rate: 1.0000e-06
# Epoch 115/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6325 - loss: 0.9027 - mean_iou: 0.3182 - val_accuracy: 0.6051 - val_loss: 0.9782 - val_mean_iou: 0.5362 - learning_rate: 1.0000e-06
# Epoch 116/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6325 - loss: 0.9027 - mean_iou: 0.3185 - val_accuracy: 0.6040 - val_loss: 0.9782 - val_mean_iou: 0.5346 - learning_rate: 1.0000e-06
# Epoch 117/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6326 - loss: 0.9026 - mean_iou: 0.3982 - val_accuracy: 0.6055 - val_loss: 0.9780 - val_mean_iou: 0.5369 - learning_rate: 1.0000e-06
# Epoch 118/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6326 - loss: 0.9026 - mean_iou: 0.3980 - val_accuracy: 0.6049 - val_loss: 0.9780 - val_mean_iou: 0.5361 - learning_rate: 1.0000e-06
# Epoch 119/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6327 - loss: 0.9024 - mean_iou: 0.3189 - val_accuracy: 0.6053 - val_loss: 0.9781 - val_mean_iou: 0.5365 - learning_rate: 1.0000e-06
# Epoch 120/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6328 - loss: 0.9024 - mean_iou: 0.3988 - val_accuracy: 0.6043 - val_loss: 0.9781 - val_mean_iou: 0.5351 - learning_rate: 1.0000e-06
# Epoch 121/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6329 - loss: 0.9023 - mean_iou: 0.3192 - val_accuracy: 0.6053 - val_loss: 0.9781 - val_mean_iou: 0.5365 - learning_rate: 1.0000e-06
# Epoch 122/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6329 - loss: 0.9022 - mean_iou: 0.3190 - val_accuracy: 0.6054 - val_loss: 0.9781 - val_mean_iou: 0.5368 - learning_rate: 1.0000e-06
# Epoch 123/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6331 - loss: 0.9021 - mean_iou: 0.3194 - val_accuracy: 0.6050 - val_loss: 0.9782 - val_mean_iou: 0.5361 - learning_rate: 1.0000e-06
# Epoch 124/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6331 - loss: 0.9020 - mean_iou: 0.3195 - val_accuracy: 0.6043 - val_loss: 0.9782 - val_mean_iou: 0.5350 - learning_rate: 1.0000e-06
# Epoch 125/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6331 - loss: 0.9021 - mean_iou: 0.3196 - val_accuracy: 0.6052 - val_loss: 0.9780 - val_mean_iou: 0.5367 - learning_rate: 1.0000e-06
# Epoch 126/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6332 - loss: 0.9019 - mean_iou: 0.3196 - val_accuracy: 0.6039 - val_loss: 0.9781 - val_mean_iou: 0.5346 - learning_rate: 1.0000e-06
# Epoch 127/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6332 - loss: 0.9018 - mean_iou: 0.3200 - val_accuracy: 0.6048 - val_loss: 0.9780 - val_mean_iou: 0.5359 - learning_rate: 1.0000e-06
# Epoch 128/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6331 - loss: 0.9018 - mean_iou: 0.3199 - val_accuracy: 0.6042 - val_loss: 0.9782 - val_mean_iou: 0.5350 - learning_rate: 1.0000e-06
# Epoch 129/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6332 - loss: 0.9017 - mean_iou: 0.3201 - val_accuracy: 0.6044 - val_loss: 0.9782 - val_mean_iou: 0.5353 - learning_rate: 1.0000e-06
# Epoch 130/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6334 - loss: 0.9017 - mean_iou: 0.4006 - val_accuracy: 0.6050 - val_loss: 0.9780 - val_mean_iou: 0.5364 - learning_rate: 1.0000e-06
# Epoch 131/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6334 - loss: 0.9017 - mean_iou: 0.4000 - val_accuracy: 0.6054 - val_loss: 0.9780 - val_mean_iou: 0.5370 - learning_rate: 1.0000e-06
# Epoch 132/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6335 - loss: 0.9015 - mean_iou: 0.4003 - val_accuracy: 0.6048 - val_loss: 0.9781 - val_mean_iou: 0.5360 - learning_rate: 1.0000e-06
# Epoch 133/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6335 - loss: 0.9015 - mean_iou: 0.4005 - val_accuracy: 0.6053 - val_loss: 0.9781 - val_mean_iou: 0.5365 - learning_rate: 1.0000e-06
# Epoch 134/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6336 - loss: 0.9015 - mean_iou: 0.4008 - val_accuracy: 0.6052 - val_loss: 0.9781 - val_mean_iou: 0.5368 - learning_rate: 1.0000e-06
# Epoch 135/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6338 - loss: 0.9015 - mean_iou: 0.4012 - val_accuracy: 0.6045 - val_loss: 0.9780 - val_mean_iou: 0.5356 - learning_rate: 1.0000e-06
# Epoch 136/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6337 - loss: 0.9013 - mean_iou: 0.4010 - val_accuracy: 0.6047 - val_loss: 0.9780 - val_mean_iou: 0.5360 - learning_rate: 1.0000e-06
# Epoch 137/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6337 - loss: 0.9013 - mean_iou: 0.4011 - val_accuracy: 0.6059 - val_loss: 0.9779 - val_mean_iou: 0.5378 - learning_rate: 1.0000e-06
# Epoch 138/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6338 - loss: 0.9012 - mean_iou: 0.4012 - val_accuracy: 0.6051 - val_loss: 0.9780 - val_mean_iou: 0.5365 - learning_rate: 1.0000e-06
# Epoch 139/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6340 - loss: 0.9012 - mean_iou: 0.4017 - val_accuracy: 0.6058 - val_loss: 0.9779 - val_mean_iou: 0.5377 - learning_rate: 1.0000e-06
# Epoch 140/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6340 - loss: 0.9011 - mean_iou: 0.4017 - val_accuracy: 0.6055 - val_loss: 0.9780 - val_mean_iou: 0.5373 - learning_rate: 1.0000e-06
# Epoch 141/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6340 - loss: 0.9010 - mean_iou: 0.4016 - val_accuracy: 0.6055 - val_loss: 0.9779 - val_mean_iou: 0.5374 - learning_rate: 1.0000e-06
# Epoch 142/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6341 - loss: 0.9010 - mean_iou: 0.4019 - val_accuracy: 0.6047 - val_loss: 0.9779 - val_mean_iou: 0.5361 - learning_rate: 1.0000e-06
# Epoch 143/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6341 - loss: 0.9009 - mean_iou: 0.4019 - val_accuracy: 0.6061 - val_loss: 0.9778 - val_mean_iou: 0.5383 - learning_rate: 1.0000e-06
# Epoch 144/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6341 - loss: 0.9009 - mean_iou: 0.4017 - val_accuracy: 0.6051 - val_loss: 0.9780 - val_mean_iou: 0.5367 - learning_rate: 1.0000e-06
# Epoch 145/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6341 - loss: 0.9009 - mean_iou: 0.4020 - val_accuracy: 0.6043 - val_loss: 0.9781 - val_mean_iou: 0.5353 - learning_rate: 1.0000e-06
# Epoch 146/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6343 - loss: 0.9008 - mean_iou: 0.4026 - val_accuracy: 0.6060 - val_loss: 0.9779 - val_mean_iou: 0.5380 - learning_rate: 1.0000e-06
# Epoch 147/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6344 - loss: 0.9007 - mean_iou: 0.4025 - val_accuracy: 0.6057 - val_loss: 0.9779 - val_mean_iou: 0.5376 - learning_rate: 1.0000e-06
# Epoch 148/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6343 - loss: 0.9006 - mean_iou: 0.4024 - val_accuracy: 0.6057 - val_loss: 0.9779 - val_mean_iou: 0.5377 - learning_rate: 1.0000e-06
# Epoch 149/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6344 - loss: 0.9006 - mean_iou: 0.4028 - val_accuracy: 0.6067 - val_loss: 0.9778 - val_mean_iou: 0.5391 - learning_rate: 1.0000e-06
# Epoch 150/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6345 - loss: 0.9005 - mean_iou: 0.4030 - val_accuracy: 0.6056 - val_loss: 0.9778 - val_mean_iou: 0.5377 - learning_rate: 1.0000e-06
# Epoch 151/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6345 - loss: 0.9005 - mean_iou: 0.4030 - val_accuracy: 0.6055 - val_loss: 0.9779 - val_mean_iou: 0.5372 - learning_rate: 1.0000e-06
# Epoch 152/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6346 - loss: 0.9005 - mean_iou: 0.4030 - val_accuracy: 0.6061 - val_loss: 0.9777 - val_mean_iou: 0.5386 - learning_rate: 1.0000e-06
# Epoch 153/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6346 - loss: 0.9004 - mean_iou: 0.4033 - val_accuracy: 0.6068 - val_loss: 0.9777 - val_mean_iou: 0.5393 - learning_rate: 1.0000e-06
# Epoch 154/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6347 - loss: 0.9004 - mean_iou: 0.4031 - val_accuracy: 0.6060 - val_loss: 0.9779 - val_mean_iou: 0.5381 - learning_rate: 1.0000e-06
# Epoch 155/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6346 - loss: 0.9004 - mean_iou: 0.4030 - val_accuracy: 0.6062 - val_loss: 0.9779 - val_mean_iou: 0.5381 - learning_rate: 1.0000e-06
# Epoch 156/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6349 - loss: 0.9002 - mean_iou: 0.4034 - val_accuracy: 0.6061 - val_loss: 0.9779 - val_mean_iou: 0.5381 - learning_rate: 1.0000e-06
# Epoch 157/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6348 - loss: 0.9002 - mean_iou: 0.4036 - val_accuracy: 0.6059 - val_loss: 0.9777 - val_mean_iou: 0.5381 - learning_rate: 1.0000e-06
# Epoch 158/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6348 - loss: 0.9002 - mean_iou: 0.4034 - val_accuracy: 0.6067 - val_loss: 0.9778 - val_mean_iou: 0.5392 - learning_rate: 1.0000e-06
# Epoch 159/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6349 - loss: 0.9001 - mean_iou: 0.3232 - val_accuracy: 0.6063 - val_loss: 0.9779 - val_mean_iou: 0.5384 - learning_rate: 1.0000e-06
# Epoch 160/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6349 - loss: 0.9001 - mean_iou: 0.4035 - val_accuracy: 0.6061 - val_loss: 0.9778 - val_mean_iou: 0.5384 - learning_rate: 1.0000e-06
# Epoch 161/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6351 - loss: 0.9000 - mean_iou: 0.4040 - val_accuracy: 0.6059 - val_loss: 0.9778 - val_mean_iou: 0.5379 - learning_rate: 1.0000e-06
# Epoch 162/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6352 - loss: 0.8999 - mean_iou: 0.4044 - val_accuracy: 0.6072 - val_loss: 0.9777 - val_mean_iou: 0.5401 - learning_rate: 1.0000e-06
# Epoch 163/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6351 - loss: 0.8999 - mean_iou: 0.4042 - val_accuracy: 0.6071 - val_loss: 0.9777 - val_mean_iou: 0.5398 - learning_rate: 1.0000e-06
# Epoch 164/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6352 - loss: 0.8999 - mean_iou: 0.3237 - val_accuracy: 0.6060 - val_loss: 0.9778 - val_mean_iou: 0.5381 - learning_rate: 1.0000e-06
# Epoch 165/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6351 - loss: 0.9000 - mean_iou: 0.4042 - val_accuracy: 0.6067 - val_loss: 0.9778 - val_mean_iou: 0.5391 - learning_rate: 1.0000e-06
# Epoch 166/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6353 - loss: 0.8997 - mean_iou: 0.4045 - val_accuracy: 0.6069 - val_loss: 0.9779 - val_mean_iou: 0.5393 - learning_rate: 1.0000e-06
# Epoch 167/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6354 - loss: 0.8997 - mean_iou: 0.4047 - val_accuracy: 0.6064 - val_loss: 0.9779 - val_mean_iou: 0.5386 - learning_rate: 1.0000e-06
# Epoch 168/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6355 - loss: 0.8997 - mean_iou: 0.4049 - val_accuracy: 0.6070 - val_loss: 0.9778 - val_mean_iou: 0.5396 - learning_rate: 1.0000e-06
# Epoch 169/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6356 - loss: 0.8996 - mean_iou: 0.4054 - val_accuracy: 0.6073 - val_loss: 0.9778 - val_mean_iou: 0.5400 - learning_rate: 1.0000e-06
# Epoch 170/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6357 - loss: 0.8996 - mean_iou: 0.4055 - val_accuracy: 0.6074 - val_loss: 0.9777 - val_mean_iou: 0.5404 - learning_rate: 1.0000e-06
# Epoch 171/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6357 - loss: 0.8996 - mean_iou: 0.4055 - val_accuracy: 0.6072 - val_loss: 0.9779 - val_mean_iou: 0.5398 - learning_rate: 1.0000e-06
# Epoch 172/200
# 783/783 - 162s - 206ms/step - accuracy: 0.6356 - loss: 0.8995 - mean_iou: 0.4054 - val_accuracy: 0.6074 - val_loss: 0.9779 - val_mean_iou: 0.5401 - learning_rate: 1.0000e-06
# Epoch 173/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6356 - loss: 0.8995 - mean_iou: 0.3245 - val_accuracy: 0.6067 - val_loss: 0.9778 - val_mean_iou: 0.5393 - learning_rate: 1.0000e-06
# Epoch 174/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6358 - loss: 0.8993 - mean_iou: 0.4061 - val_accuracy: 0.6069 - val_loss: 0.9778 - val_mean_iou: 0.5396 - learning_rate: 1.0000e-06
# Epoch 175/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6358 - loss: 0.8992 - mean_iou: 0.3249 - val_accuracy: 0.6071 - val_loss: 0.9777 - val_mean_iou: 0.5399 - learning_rate: 1.0000e-06
# Epoch 176/200
# 783/783 - 162s - 208ms/step - accuracy: 0.6358 - loss: 0.8992 - mean_iou: 0.4063 - val_accuracy: 0.6070 - val_loss: 0.9777 - val_mean_iou: 0.5398 - learning_rate: 1.0000e-06
# Epoch 177/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6359 - loss: 0.8991 - mean_iou: 0.4063 - val_accuracy: 0.6067 - val_loss: 0.9779 - val_mean_iou: 0.5392 - learning_rate: 1.0000e-06
# Epoch 178/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6360 - loss: 0.8991 - mean_iou: 0.4064 - val_accuracy: 0.6074 - val_loss: 0.9778 - val_mean_iou: 0.5404 - learning_rate: 1.0000e-06
# Epoch 179/200
# 783/783 - 162s - 206ms/step - accuracy: 0.6359 - loss: 0.8991 - mean_iou: 0.3251 - val_accuracy: 0.6061 - val_loss: 0.9779 - val_mean_iou: 0.5383 - learning_rate: 1.0000e-06
# Epoch 180/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6360 - loss: 0.8990 - mean_iou: 0.4067 - val_accuracy: 0.6076 - val_loss: 0.9778 - val_mean_iou: 0.5406 - learning_rate: 1.0000e-06
# Epoch 181/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6361 - loss: 0.8989 - mean_iou: 0.4067 - val_accuracy: 0.6070 - val_loss: 0.9779 - val_mean_iou: 0.5397 - learning_rate: 1.0000e-06
# Epoch 182/200
# 783/783 - 162s - 206ms/step - accuracy: 0.6363 - loss: 0.8989 - mean_iou: 0.4071 - val_accuracy: 0.6070 - val_loss: 0.9778 - val_mean_iou: 0.5399 - learning_rate: 1.0000e-06
# Epoch 183/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6364 - loss: 0.8988 - mean_iou: 0.4075 - val_accuracy: 0.6077 - val_loss: 0.9777 - val_mean_iou: 0.5408 - learning_rate: 1.0000e-06
# Epoch 184/200
# 783/783 - 162s - 206ms/step - accuracy: 0.6363 - loss: 0.8989 - mean_iou: 0.3257 - val_accuracy: 0.6069 - val_loss: 0.9779 - val_mean_iou: 0.5395 - learning_rate: 1.0000e-06
# Epoch 185/200
# 783/783 - 162s - 207ms/step - accuracy: 0.6365 - loss: 0.8987 - mean_iou: 0.4073 - val_accuracy: 0.6076 - val_loss: 0.9779 - val_mean_iou: 0.5406 - learning_rate: 1.0000e-06
# Epoch 186/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6365 - loss: 0.8987 - mean_iou: 0.4075 - val_accuracy: 0.6073 - val_loss: 0.9778 - val_mean_iou: 0.5404 - learning_rate: 1.0000e-06
# Epoch 187/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6364 - loss: 0.8988 - mean_iou: 0.4075 - val_accuracy: 0.6069 - val_loss: 0.9778 - val_mean_iou: 0.5396 - learning_rate: 1.0000e-06
# Epoch 188/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6366 - loss: 0.8985 - mean_iou: 0.4078 - val_accuracy: 0.6067 - val_loss: 0.9779 - val_mean_iou: 0.5393 - learning_rate: 1.0000e-06
# Epoch 189/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6367 - loss: 0.8985 - mean_iou: 0.4082 - val_accuracy: 0.6075 - val_loss: 0.9778 - val_mean_iou: 0.5405 - learning_rate: 1.0000e-06
# Epoch 190/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6367 - loss: 0.8985 - mean_iou: 0.4080 - val_accuracy: 0.6071 - val_loss: 0.9779 - val_mean_iou: 0.5396 - learning_rate: 1.0000e-06
# Epoch 191/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6369 - loss: 0.8985 - mean_iou: 0.4081 - val_accuracy: 0.6067 - val_loss: 0.9779 - val_mean_iou: 0.5393 - learning_rate: 1.0000e-06
# Epoch 192/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6369 - loss: 0.8984 - mean_iou: 0.4085 - val_accuracy: 0.6067 - val_loss: 0.9779 - val_mean_iou: 0.5392 - learning_rate: 1.0000e-06
# Epoch 193/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6369 - loss: 0.8983 - mean_iou: 0.4083 - val_accuracy: 0.6071 - val_loss: 0.9779 - val_mean_iou: 0.5398 - learning_rate: 1.0000e-06
# Epoch 194/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6372 - loss: 0.8984 - mean_iou: 0.4090 - val_accuracy: 0.6080 - val_loss: 0.9778 - val_mean_iou: 0.5412 - learning_rate: 1.0000e-06
# Epoch 195/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6370 - loss: 0.8983 - mean_iou: 0.4086 - val_accuracy: 0.6067 - val_loss: 0.9780 - val_mean_iou: 0.5391 - learning_rate: 1.0000e-06
# Epoch 196/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6370 - loss: 0.8983 - mean_iou: 0.3270 - val_accuracy: 0.6072 - val_loss: 0.9779 - val_mean_iou: 0.5400 - learning_rate: 1.0000e-06
# Epoch 197/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6373 - loss: 0.8982 - mean_iou: 0.4092 - val_accuracy: 0.6073 - val_loss: 0.9779 - val_mean_iou: 0.5401 - learning_rate: 1.0000e-06
# Epoch 198/200
# 783/783 - 163s - 209ms/step - accuracy: 0.6371 - loss: 0.8981 - mean_iou: 0.4090 - val_accuracy: 0.6076 - val_loss: 0.9779 - val_mean_iou: 0.5406 - learning_rate: 1.0000e-06
# Epoch 199/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6374 - loss: 0.8980 - mean_iou: 0.3274 - val_accuracy: 0.6073 - val_loss: 0.9779 - val_mean_iou: 0.5399 - learning_rate: 1.0000e-06
# Epoch 200/200
# 783/783 - 163s - 208ms/step - accuracy: 0.6375 - loss: 0.8980 - mean_iou: 0.4097 - val_accuracy: 0.6073 - val_loss: 0.9778 - val_mean_iou: 0.5401 - learning_rate: 1.0000e-06
# Final validation Mean Intersection Over Union: 54.12%

# %%
model_filename = 'UNet_'+str(final_val_meanIoU)+'.keras'
model.save(model_filename)

# %%
test_loss, test_accuracy, test_mean_iou = model.evaluate(X_test_tf)

# Print the results
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Mean IoU: {test_mean_iou}")
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.6462 - loss: 0.9775 - mean_iou: 0.5643
# Test Loss: 0.9776154160499573
# Test Accuracy: 0.6390791535377502
# Test Mean IoU: 0.5584849715232849

# %%
y_preds = model.predict(X_to_predict_tf)
y_preds = np.argmax(y_preds, axis=-1)
print(f"Predictions shape: {y_preds.shape}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step
# Predictions shape: (10022, 64, 128)

# %%
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = f'UNet_{test_mean_iou}'
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(y_preds)
submission_df.to_csv(submission_filename, index=False)
